# %%
import json
import pandas as pd

# Ruta al JSON que generaste
with open("booking_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Convertir a DataFrame
df = pd.DataFrame(data)

# Ver primeras filas

# %%
df
# Out:
#                                                 title   price          rating  \
# 0             Departamento Playas Villamil vacaciones   US$57             9,1
# 1                              Habitaciones Guadalupe   US$20             1,0
# 2                             Suite frente a la playa   US$36             9,2
# 3                 Radiante departamento frente al mar  US$164             9,7
# 4                        Ocean Club - Ocean Suites II  US$110             9,3
# ..                                                ...     ...             ...
# 394  VILLA SANTORO Casa playa de Castelnuovo-Atacames   US$76  Sin puntuación
# 395                           Casa vacacional tonsupa   US$60  Sin puntuación
# 396                     Suite en la Playa de Atacames   US$90             9,5
# 397                         Dpto PUNTA ARENA ATACAMES  US$160  Sin puntuación
# 398             Departamento para 6 personas Atacames  US$200  Sin puntuación
#
#                 distance features payment_policy  \
# 0    a 2,5 km del centro
# 1      a 1 km del centro
# 2     a 400 m del centro
# 3    a 3,4 km del centro
# 4    a 3,5 km del centro
# ..                   ...      ...            ...
# 394  a 2,5 km del centro
# 395  a 0,6 km del centro
# 396  a 0,9 km del centro
# 397  a 1,3 km del centro
# 398  a 1,3 km del centro
#
#                                                    url        beach_distance  \
# 0    https://www.booking.com/hotel/ec/departamento-...   A 450 m de la playa
# 1    https://www.booking.com/hotel/ec/habitaciones-...   A 850 m de la playa
# 2    https://www.booking.com/hotel/ec/suite-frente-...     Frente a la playa
# 3    https://www.booking.com/hotel/ec/radiante-depa...   A 100 m de la playa
# 4    https://www.booking.com/hotel/ec/ocean-club-oc...     Frente a la playa
# ..                                                 ...                   ...
# 394  https://www.booking.com/hotel/ec/villa-santoro...     Frente a la playa
# 395  https://www.booking.com/hotel/ec/casa-vacacion...  A 1,3 km de la playa
# 396  https://www.booking.com/hotel/ec/suite-en-la-p...     Frente a la playa
# 397  https://www.booking.com/hotel/ec/dpto-punta-ar...     Frente a la playa
# 398  https://www.booking.com/hotel/ec/departamento-...     Frente a la playa
#
#              destino                                         search_url  \
# 0    Villamil Playas  https://www.booking.com/searchresults.es.html?...
# 1    Villamil Playas  https://www.booking.com/searchresults.es.html?...
# 2    Villamil Playas  https://www.booking.com/searchresults.es.html?...
# 3    Villamil Playas  https://www.booking.com/searchresults.es.html?...
# 4    Villamil Playas  https://www.booking.com/searchresults.es.html?...
# ..               ...                                                ...
# 394         Atacames  https://www.booking.com/searchresults.es.html?...
# 395         Atacames  https://www.booking.com/searchresults.es.html?...
# 396         Atacames  https://www.booking.com/searchresults.es.html?...
# 397         Atacames  https://www.booking.com/searchresults.es.html?...
# 398         Atacames  https://www.booking.com/searchresults.es.html?...
#
#                                            description  \
# 0    Departamento Playas Villamil vacaciones se enc...
# 1    Habitaciones Guadalupe es un alojamiento que e...
# 2    Suite frente a la playa, que cuenta con vistas...
# 3    Radiante departamento frente al mar está en Ge...
# 4    Ocean Club - Ocean Suites II, que cuenta con p...
# ..                                                 ...
# 394  VILLA SANTORO Casa playa de Castelnuovo-Atacam...
# 395  Casa vacacional tonsupa está en Atacames y dis...
# 396  Suite en la Playa de Atacames, que tiene pisci...
# 397  Dpto PUNTA ARENA ATACAMES está en Atacames, a ...
# 398  Departamento para 6 personas Atacames se encue...
#
#                                   location  \
# 0         -2.652294609238,-80.375668932982
# 1                   -2.6285225,-80.3963382
# 2         -2.635641363638,-80.394838328767
# 3    -2.6430971001678403,-80.4207856326357
# 4       -2.64332067873866,-80.421355309401
# ..                                     ...
# 394   0.8815743261389231,-79.8330169427071
# 395    0.862236754969483,-79.8464402357249
# 396    0.8688447856279999,-79.857434261419
# 397      0.866300185129399,-79.86201329695
# 398    0.866314000116283,-79.8619856973141
#
#                                               services  \
# 0    [Piscina al aire libre, Habitaciones sin humo,...
# 1                                     [Parking gratis]
# 2    [Parking gratis, Adaptado personas de movilida...
# 3    [Piscina, Habitaciones sin humo, Parking grati...
# 4    [3 piscinas, Parking gratis, 2 restaurantes, W...
# ..                                                 ...
# 394  [Parking gratis, WiFi gratis, Habitaciones sin...
# 395                             [Piscina, WiFi gratis]
# 396  [Piscina al aire libre, Parking gratis, Habita...
# 397  [Piscina al aire libre, Parking gratis, WiFi g...
# 398  [2 piscinas, Parking gratis, WiFi gratis, Habi...
#
#                             pointService  \
# 0                                    9.1
# 1                                      1
# 2                                    9.2
# 3                                    9.7
# 4                                    9.3
# ..                                   ...
# 394  Puntaje de Servicios no disponibles
# 395  Puntaje de Servicios no disponibles
# 396                                  9.5
# 397  Puntaje de Servicios no disponibles
# 398  Puntaje de Servicios no disponibles
#
#                                                reviews
# 0    [{'title': 'Mejores vacaciones', 'date': 'Fech...
# 1    [{'title': 'Pésimo', 'date': 'Fecha del coment...
# 2    [{'title': 'Excepcional', 'date': 'Fecha del c...
# 3    [{'title': 'Cómodo y buena ubicación', 'date':...
# 4    [{'title': 'Acogedor, còmodo y funcional', 'da...
# ..                                                 ...
# 394                                                 []
# 395                                                 []
# 396  [{'title': 'Fantástico', 'date': 'Fecha del co...
# 397                                                 []
# 398                                                 []
#
# [399 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           399 non-null    object
#  1   price           399 non-null    object
#  2   rating          399 non-null    object
#  3   distance        399 non-null    object
#  4   features        399 non-null    object
#  5   payment_policy  399 non-null    object
#  6   url             399 non-null    object
#  7   beach_distance  399 non-null    object
#  8   destino         399 non-null    object
#  9   search_url      399 non-null    object
#  10  description     399 non-null    object
#  11  location        399 non-null    object
#  12  services        399 non-null    object
#  13  pointService    399 non-null    object
#  14  reviews         399 non-null    object
# dtypes: object(15)
# memory usage: 46.9+ KB

# %%
# Convertir price a número (solo el valor numérico)
df["price_num"] = df["price"].str.replace(r"[^\d,]", "", regex=True).str.replace(",", ".").astype(float)

# Convertir rating y pointService a float
df["rating"] = df["rating"].str.replace(",", ".").astype(float, errors="ignore")
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

df["pointService"] = df["pointService"].astype(float, errors="ignore")

# %%
df["destino"] = df["destino"].str.lower().str.strip().astype("str")

# %%
df.head(3)
# Out:
#                                      title  price  rating  \
# 0  Departamento Playas Villamil vacaciones  US$57     9.1
# 1                   Habitaciones Guadalupe  US$20     1.0
# 2                  Suite frente a la playa  US$36     9.2
#
#               distance features payment_policy  \
# 0  a 2,5 km del centro
# 1    a 1 km del centro
# 2   a 400 m del centro
#
#                                                  url       beach_distance  \
# 0  https://www.booking.com/hotel/ec/departamento-...  A 450 m de la playa
# 1  https://www.booking.com/hotel/ec/habitaciones-...  A 850 m de la playa
# 2  https://www.booking.com/hotel/ec/suite-frente-...    Frente a la playa
#
#            destino                                         search_url  \
# 0  villamil playas  https://www.booking.com/searchresults.es.html?...
# 1  villamil playas  https://www.booking.com/searchresults.es.html?...
# 2  villamil playas  https://www.booking.com/searchresults.es.html?...
#
#                                          description  \
# 0  Departamento Playas Villamil vacaciones se enc...
# 1  Habitaciones Guadalupe es un alojamiento que e...
# 2  Suite frente a la playa, que cuenta con vistas...
#
#                            location  \
# 0  -2.652294609238,-80.375668932982
# 1            -2.6285225,-80.3963382
# 2  -2.635641363638,-80.394838328767
#
#                                             services pointService  \
# 0  [Piscina al aire libre, Habitaciones sin humo,...          9.1
# 1                                   [Parking gratis]            1
# 2  [Parking gratis, Adaptado personas de movilida...          9.2
#
#                                              reviews  price_num
# 0  [{'title': 'Mejores vacaciones', 'date': 'Fech...       57.0
# 1  [{'title': 'Pésimo', 'date': 'Fecha del coment...       20.0
# 2  [{'title': 'Excepcional', 'date': 'Fecha del c...       36.0

# %%
df.groupby("destino")["rating"].mean().round(2).sort_values(ascending=False)
# Out:
# destino
# salinas            8.81
# ayampe             8.79
# manta              8.56
# villamil playas    8.52
# montañita          8.50
# puerto lopez       8.42
# atacames           8.21
# Name: rating, dtype: float64

# %%
# Corrección bayesiana
df["n_reviews"] = df["reviews"].apply(len)
df["weighted_score"] = (df["rating"] * (df["n_reviews"] / (df["n_reviews"] + 2))).round(2)

# %%
df.head()
# Out:
#                                      title   price  rating  \
# 0  Departamento Playas Villamil vacaciones   US$57     9.1
# 1                   Habitaciones Guadalupe   US$20     1.0
# 2                  Suite frente a la playa   US$36     9.2
# 3      Radiante departamento frente al mar  US$164     9.7
# 4             Ocean Club - Ocean Suites II  US$110     9.3
#
#               distance features payment_policy  \
# 0  a 2,5 km del centro
# 1    a 1 km del centro
# 2   a 400 m del centro
# 3  a 3,4 km del centro
# 4  a 3,5 km del centro
#
#                                                  url       beach_distance  \
# 0  https://www.booking.com/hotel/ec/departamento-...  A 450 m de la playa
# 1  https://www.booking.com/hotel/ec/habitaciones-...  A 850 m de la playa
# 2  https://www.booking.com/hotel/ec/suite-frente-...    Frente a la playa
# 3  https://www.booking.com/hotel/ec/radiante-depa...  A 100 m de la playa
# 4  https://www.booking.com/hotel/ec/ocean-club-oc...    Frente a la playa
#
#            destino                                         search_url  \
# 0  villamil playas  https://www.booking.com/searchresults.es.html?...
# 1  villamil playas  https://www.booking.com/searchresults.es.html?...
# 2  villamil playas  https://www.booking.com/searchresults.es.html?...
# 3  villamil playas  https://www.booking.com/searchresults.es.html?...
# 4  villamil playas  https://www.booking.com/searchresults.es.html?...
#
#                                          description  \
# 0  Departamento Playas Villamil vacaciones se enc...
# 1  Habitaciones Guadalupe es un alojamiento que e...
# 2  Suite frente a la playa, que cuenta con vistas...
# 3  Radiante departamento frente al mar está en Ge...
# 4  Ocean Club - Ocean Suites II, que cuenta con p...
#
#                                 location  \
# 0       -2.652294609238,-80.375668932982
# 1                 -2.6285225,-80.3963382
# 2       -2.635641363638,-80.394838328767
# 3  -2.6430971001678403,-80.4207856326357
# 4     -2.64332067873866,-80.421355309401
#
#                                             services pointService  \
# 0  [Piscina al aire libre, Habitaciones sin humo,...          9.1
# 1                                   [Parking gratis]            1
# 2  [Parking gratis, Adaptado personas de movilida...          9.2
# 3  [Piscina, Habitaciones sin humo, Parking grati...          9.7
# 4  [3 piscinas, Parking gratis, 2 restaurantes, W...          9.3
#
#                                              reviews  price_num  n_reviews  \
# 0  [{'title': 'Mejores vacaciones', 'date': 'Fech...       57.0          5
# 1  [{'title': 'Pésimo', 'date': 'Fecha del coment...       20.0          1
# 2  [{'title': 'Excepcional', 'date': 'Fecha del c...       36.0          2
# 3  [{'title': 'Cómodo y buena ubicación', 'date':...      164.0          6
# 4  [{'title': 'Acogedor, còmodo y funcional', 'da...      110.0          7
#
#    weighted_score
# 0            6.50
# 1            0.33
# 2            4.60
# 3            7.28
# 4            7.23

# %%
def separar_resenas_por_sentimiento(reviews):
    positivos, negativos = [], []
    if isinstance(reviews, list):
        for r in reviews:
            pos = r.get("positive_feedback", "").strip()
            neg = r.get("negative_feedback", "").strip()
            if pos and pos.lower() not in ["n/a", "na", "no aplica"]:
                positivos.append(pos)
            if neg and neg.lower() not in ["n/a", "na", "no aplica"]:
                negativos.append(neg)
    return " ".join(positivos), " ".join(negativos)

# %%
# Crear columnas separadas
df[["resenas_positivas", "resenas_negativas"]] = df["reviews"].apply(
    lambda x: pd.Series(separar_resenas_por_sentimiento(x))
)

# %%
# Forzar conversión segura a float / int
df["weighted_score"] = pd.to_numeric(df["weighted_score"], errors="coerce")
df["pointService"] = pd.to_numeric(df["pointService"], errors="coerce")
df["price_num"] = pd.to_numeric(df["price_num"], errors="coerce")
df["n_reviews"] = pd.to_numeric(df["n_reviews"], errors="coerce")

# %%
destinos_grouped = (
    df.groupby("destino", dropna=False)
      .agg({
          "weighted_score": "mean",
          "pointService": "mean",
          "price_num": "mean",
          "n_reviews": "sum",
          "resenas_positivas": lambda x: " ".join(filter(None, x)),
          "resenas_negativas": lambda x: " ".join(filter(None, x)),
          "title" : "count",
      })
      .reset_index()
)

# %%
#
destinos_grouped.rename(columns={"title": "n_hoteles"}, inplace=True)

# %%
destinos_grouped["n_hoteles"] = pd.to_numeric(destinos_grouped["n_hoteles"], errors="coerce")

# %%
print(df[["weighted_score", "pointService", "price_num", "n_reviews"]].dtypes)
# Out:
# weighted_score    float64
# pointService      float64
# price_num         float64
# n_reviews           int64
# dtype: object

# %%
destinos_grouped
# Out:
#            destino  weighted_score  pointService   price_num  n_reviews  \
# 0         atacames        6.069524      8.214286   68.481481        138
# 1           ayampe        6.690606      8.792424   65.253333        463
# 2            manta        5.997115      8.555769   71.959459        301
# 3        montañita        6.373158      8.500000   54.693878        257
# 4     puerto lopez        6.387500      8.418750   59.333333        216
# 5          salinas        6.150862      8.813793   87.367647        338
# 6  villamil playas        5.790877      8.521053  121.828571        312
#
#                                    resenas_positivas  \
# 0  La señora de recepcion muy amable. Las instlac...
# 1  Todo Bello diseño Matteo, el anfitrión del hos...
# 2  La atención es personalizada y muy atentos El ...
# 3  Me gustó la habitación y el baño súper limpios...
# 4  El lugar súper tranquilo y lindo Las personas ...
# 5  las instalaciones son bonitas y la atencion po...
# 6  Limpieza y organización Muy acogedor La comodi...
#
#                                    resenas_negativas  n_hoteles
# 0  EL parqueadero queda a dos cuadras, pero nada ...         27
# 1  Nada Nada la verdad que todo 10/10 Aunque es m...         75
# 2  Hubiera sido bueno una opción de desayuno cost...         74
# 3  mejoraría el desayuno Que la piscina esté un p...         49
# 4  Está lindo el lugar Que el día sábado para ama...         36
# 5  no tenia conexión a ninguna canal de televisió...         68
# 6  Las calles al rededor están en mal estado y ll...         70

# %%
# pip install openai python-dotenv

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
# Cargar variables desde .env
load_dotenv()

# Leer la API key
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# Verificación opcional (no obligatoria)
if not OPENAI_API_KEY:
    raise ValueError("❌ No se encontró la variable OPENAI_API_KEY. Revisa tu archivo .env")

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
def analizar_destino_gpt(nombre, positivos, negativos, score, servicios, n_hoteles):
    # Cortar texto si hay demasiadas reseñas (máx 3500 tokens aprox)
    positivos = (positivos or "")[:2500]
    negativos = (negativos or "")[:2500]

    prompt = f"""
    Analiza las reseñas para el destino turístico **{nombre}** en Ecuador.

    Contexto numérico:
    - Puntaje corregido (weighted_score): {score}
    - Promedio de servicios (pointService): {servicios}
    - Número de hoteles analizados: {n_hoteles}

    A continuación tienes dos bloques de comentarios:

    --- COMENTARIOS POSITIVOS ---
    {positivos}

    --- COMENTARIOS NEGATIVOS ---
    {negativos}

    Con base en estos datos:
    1. Resume los aspectos positivos y negativos más comunes.
    2. Evalúa el nivel de hospitalidad percibida (1 a 10).
    3. Describe brevemente el perfil del destino (tranquilo, familiar, fiestero, etc.).
    4. Sugiere si sería recomendable para nuevas inversiones turísticas.
    """

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3
    )
    return response.choices[0].message.content.strip()

# %%
import time

def generar_analisis_por_destino(df):
    resultados = []
    for _, row in df.iterrows():
        try:
            print(f"Analizando destino: {row['destino']} ...")
            analisis = analizar_destino_gpt(
                nombre=row["destino"],
                positivos=row["resenas_positivas"],
                negativos=row["resenas_negativas"],
                score=row["weighted_score"],
                servicios=row["pointService"],
                n_hoteles=row["n_hoteles"]
            )
            resultados.append(analisis)
            time.sleep(2)  # para no saturar la API
        except Exception as e:
            print(f"Error con {row['destino']}: {e}")
            resultados.append(None)
    df["analisis_gpt"] = resultados
    return df

destinos_grouped = generar_analisis_por_destino(destinos_grouped)
# Out:
# Analizando destino: atacames ...
# Analizando destino: ayampe ...
# Analizando destino: manta ...
# Analizando destino: montañita ...
# Analizando destino: puerto lopez ...
# Analizando destino: salinas ...
# Analizando destino: villamil playas ...

# %%
destinos_grouped
# Out:
#            destino  weighted_score  pointService   price_num  n_reviews  \
# 0         atacames        6.069524      8.214286   68.481481        138
# 1           ayampe        6.690606      8.792424   65.253333        463
# 2            manta        5.997115      8.555769   71.959459        301
# 3        montañita        6.373158      8.500000   54.693878        257
# 4     puerto lopez        6.387500      8.418750   59.333333        216
# 5          salinas        6.150862      8.813793   87.367647        338
# 6  villamil playas        5.790877      8.521053  121.828571        312
#
#                                    resenas_positivas  \
# 0  La señora de recepcion muy amable. Las instlac...
# 1  Todo Bello diseño Matteo, el anfitrión del hos...
# 2  La atención es personalizada y muy atentos El ...
# 3  Me gustó la habitación y el baño súper limpios...
# 4  El lugar súper tranquilo y lindo Las personas ...
# 5  las instalaciones son bonitas y la atencion po...
# 6  Limpieza y organización Muy acogedor La comodi...
#
#                                    resenas_negativas  n_hoteles  \
# 0  EL parqueadero queda a dos cuadras, pero nada ...         27
# 1  Nada Nada la verdad que todo 10/10 Aunque es m...         75
# 2  Hubiera sido bueno una opción de desayuno cost...         74
# 3  mejoraría el desayuno Que la piscina esté un p...         49
# 4  Está lindo el lugar Que el día sábado para ama...         36
# 5  no tenia conexión a ninguna canal de televisió...         68
# 6  Las calles al rededor están en mal estado y ll...         70
#
#                                         analisis_gpt
# 0  1. **Aspectos Positivos y Negativos Comunes:**...
# 1  1. **Aspectos Positivos y Negativos Más Comune...
# 2  1. **Aspectos positivos y negativos más comune...
# 3  1. **Aspectos positivos y negativos más comune...
# 4  1. **Aspectos positivos y negativos más comune...
# 5  1. **Aspectos positivos y negativos más comune...
# 6  1. **Aspectos Positivos y Negativos Comunes:**...

# %%
destinos_grouped.columns
# Out:
# Index(['destino', 'weighted_score', 'pointService', 'price_num', 'n_reviews',
#        'resenas_positivas', 'resenas_negativas', 'n_hoteles', 'analisis_gpt'],
#       dtype='object')

# %%
import json

# Convertir a lista de diccionarios
data_json = destinos_grouped[['destino', 'weighted_score', 'pointService', 'price_num', 'n_reviews', 'n_hoteles', 'analisis_gpt']].to_dict(orient="records")

# Guardar en archivo
with open("analisis_destinos.json", "w", encoding="utf-8") as f:
    json.dump(data_json, f, ensure_ascii=False, indent=4)

print("✅ Archivo guardado: analisis_destinos.json")
# Out:
# ✅ Archivo guardado: analisis_destinos.json
